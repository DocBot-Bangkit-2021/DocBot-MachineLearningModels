# %% [markdown]
# <a href="https://colab.research.google.com/github/DocBot-Bangkit-2021/DocBot-MachineLearningModels/blob/main/Covid-19/Covid19_Baseline_Model_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Import Library**

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
import zipfile
import os

# %%
plt.style.use('seaborn')

# %% [markdown]
# # **Data Loading**
#
# [Early stage symptoms of COVID-19 patient's](https://www.kaggle.com/martuza/early-stage-symptoms-of-covid19-patients)
#
# ### **A machine learning model to identify early stage symptoms of SARS-Cov-2 infected patients**
#
# ### **Dataset description**
#
# The dataset contains 6,512 individuals with follows attributes :
#
# * `Gender` - (male, female)
# * `Age` - (Numeric)
# * `Fever` - (yes-1, no-0)
# * `Cough` - (yes-1, no-0)
# * `Runny nose` - (yes-1, no-0)
# * `Muscle soreness` - (yes-1, no-0)
# * `Pneumonia` - (yes-1, no-0)
# * `Diarrhea` - (yes-1, no-0)
# * `Lung infection` - (yes-1, no-0)
# * `Travel history` - (yes-1, no-0)
# * `Isolation treatment` - (yes-1, no-0)
# * `SARS-CoV-2 Positive` - (positive-1, suspected-0)
#
# ### **Related paper**
#
# [A machine learning model to identify early stage symptoms of SARS-Cov-2 infected patients](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7305929/)
#
# Ahamad MM, Aktar S, Rashed-Al-Mahfuz M, et al. A machine learning model to identify early stage symptoms of SARS-Cov-2 infected patients. Expert Systems with Applications. 2020;160:113661. doi:10.1016/j.eswa.2020.113661

# %% [markdown]
# ## **Download dataset from Kaggle**
#
# How to get data from kaggle :
# https://www.kaggle.com/general/51898

# %%
# Upload kaggle.json 
print("Upload your kaggle.json")
from google.colab import files
kaggle_file = files.upload()

# Change file permission
! chmod 600 kaggle.json 
# Check or make kaggle folder
! (ls ~/.kaggle 2>/dev/null || mkdir ~/.kaggle)
# Move kaggle.json to kaggle folder
! mv kaggle.json ~/.kaggle/ && echo 'Done'
# Download dataset from kaggle
! kaggle datasets download -d martuza/early-stage-symptoms-of-covid19-patients

# unzipping/extract data .zip
# file_zip = 'early-stage-symptoms-of-covid19-patients.zip'
# with zipfile.ZipFile(file_zip) as zip_file:
#     zip_file.extractall('./sars-cov-2/')
file_zip = 'early-stage-symptoms-of-covid19-patients.zip'
zip_ref = zipfile.ZipFile(file_zip, 'r')
zip_ref.extractall('./sars-cov-2/')
zip_ref.close()

print('Done')
print(os.listdir('./sars-cov-2/'))
# Out:
# Upload your kaggle.json
#      <input type="file" id="files-30ce235d-0644-4e9f-a7fd-bdc0cbbb0e8c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-30ce235d-0644-4e9f-a7fd-bdc0cbbb0e8c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# Done
# Downloading early-stage-symptoms-of-covid19-patients.zip to /content
#   0% 0.00/15.5k [00:00<?, ?B/s]
# 100% 15.5k/15.5k [00:00<00:00, 27.7MB/s]
# Done
# ['covid_early_stage_symptoms.csv']

# %%
import pandas as pd
df = pd.read_csv('sars-cov-2/covid_early_stage_symptoms.csv')
df.head()
# Out:
#   gender  age_year  ...  isolation_treatment  SARS-CoV-2 Positive
# 0   male        89  ...                    0                    0
# 1   male        68  ...                    0                    0
# 2   male        68  ...                    0                    0
# 3   male        68  ...                    1                    1
# 4   male        50  ...                    0                    1
#
# [5 rows x 12 columns]

# %% [markdown]
# ## **Download dataset from GDrive [Optional]**

# %%
# import pandas as pd
# df = pd.read_csv('https://drive.google.com/uc?id=11w6cKQANeVoWnbjNJ8RQy2BLomdfCTBJ')
# df.head()

# %% [markdown]
# ## **Download dataset from GitHub [Optional]**

# %%
# import pandas as pd
# df = pd.read_csv('https://raw.githubusercontent.com/DocBot-Bangkit-2021/DocBot-MachineLearningModels/main/Covid-19/covid_early_stage_symptoms.csv')
# df.head()

# %% [markdown]
# # **Exploratory Data Analyis (EDA)**

# %% [markdown]
# Displays a list of columns

# %%
# column list
df.columns
# Out:
# Index(['gender', 'age_year', 'fever', 'cough', 'runny_nose', 'muscle_soreness',
#        'pneumonia', 'diarrhea', 'lung_infection', 'travel_history',
#        'isolation_treatment', 'SARS-CoV-2 Positive'],
#       dtype='object')

# %%
# statistical description of the data
df.describe()
# Out:
#           age_year        fever  ...  isolation_treatment  SARS-CoV-2 Positive
# count  6512.000000  6512.000000  ...          6512.000000          6512.000000
# mean     44.019502     0.410780  ...             0.216984             0.241400
# std      16.112865     0.492013  ...             0.412223             0.427965
# min       1.000000     0.000000  ...             0.000000             0.000000
# 25%      32.000000     0.000000  ...             0.000000             0.000000
# 50%      43.000000     0.000000  ...             0.000000             0.000000
# 75%      55.000000     1.000000  ...             0.000000             0.000000
# max      96.000000     1.000000  ...             1.000000             1.000000
#
# [8 rows x 11 columns]

# %%
# additional info about data: type, number of nulls, number of rows and others
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6512 entries, 0 to 6511
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   gender               6512 non-null   object
#  1   age_year             6512 non-null   int64
#  2   fever                6512 non-null   int64
#  3   cough                6512 non-null   int64
#  4   runny_nose           6512 non-null   int64
#  5   muscle_soreness      6512 non-null   int64
#  6   pneumonia            6512 non-null   int64
#  7   diarrhea             6512 non-null   int64
#  8   lung_infection       6512 non-null   int64
#  9   travel_history       6512 non-null   int64
#  10  isolation_treatment  6512 non-null   int64
#  11  SARS-CoV-2 Positive  6512 non-null   int64
# dtypes: int64(11), object(1)
# memory usage: 610.6+ KB

# %%
# check for null counts
df.isnull().sum()
# Out:
# gender                 0
# age_year               0
# fever                  0
# cough                  0
# runny_nose             0
# muscle_soreness        0
# pneumonia              0
# diarrhea               0
# lung_infection         0
# travel_history         0
# isolation_treatment    0
# SARS-CoV-2 Positive    0
# dtype: int64

# %%
# large amount of data based on SARS-CoV-2 Positive target - (positive-1, Suspected-0)
df["SARS-CoV-2 Positive"].value_counts()
# Out:
# 0    4940
# 1    1572
# Name: SARS-CoV-2 Positive, dtype: int64

# %%
# the number of rows and columns in the data
print('Total Row:', df.shape[0])
print('Total Columns:', df.shape[1])
df.shape
# Out:
# Total Row: 6512
# Total Columns: 12
# (6512, 12)

# %%
# defines the column category and the amount in each type
col_cat = ['gender', 'fever', 'cough', 'runny_nose', 'muscle_soreness',
       'pneumonia', 'diarrhea', 'lung_infection', 'travel_history',
       'isolation_treatment', 'SARS-CoV-2 Positive']
for col in col_cat :
  print(df[col].value_counts(), "\n")
# Out:
# male      3367
# female    3145
# Name: gender, dtype: int64
#
# 0    3837
# 1    2675
# Name: fever, dtype: int64
#
# 0    4537
# 1    1975
# Name: cough, dtype: int64
#
# 0    5963
# 1     549
# Name: runny_nose, dtype: int64
#
# 0    6486
# 1      26
# Name: muscle_soreness, dtype: int64
#
# 0    6025
# 1     487
# Name: pneumonia, dtype: int64
#
# 0    6475
# 1      37
# Name: diarrhea, dtype: int64
#
# 0    5657
# 1     855
# Name: lung_infection, dtype: int64
#
# 1    4239
# 0    2273
# Name: travel_history, dtype: int64
#
# 0    5099
# 1    1413
# Name: isolation_treatment, dtype: int64
#
# 0    4940
# 1    1572
# Name: SARS-CoV-2 Positive, dtype: int64

# %% [markdown]
# # **Data Visualization**

# %%
# display of data distribution distribution on SARS-CoV-2 Positive - (positive-1, Suspected-0)
sns.countplot(df['SARS-CoV-2 Positive'], label="SARS-CoV-2 Positive")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# SARS-CoV-2 Positive
# positive --> 1
# Suspected --> 0
df['SARS-CoV-2 Positive'].unique()
# Out:
# array([0, 1])

# %%
target = df['SARS-CoV-2 Positive'].value_counts()
label =['Suspected', 'Positif']
target.plot(kind='pie', labels=label, autopct='%1.1f%%')
plt.title('SARS-CoV-2 Positive Presentation')
plt.show()

# %%
fig = plt.figure(figsize=(20, 20))
axs = fig.add_subplot()
df.hist(ax=axs);
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
plt.figure(figsize=(20,12)) 
sns.heatmap(df.corr(), annot=True)

# %% [markdown]
# # Data cleaning
# check missing value, Check duplicate value, check data type, check outlier, check typo, check imbalance data

# %% [markdown]
# ## -- Check missing value

# %%
# Check missing value
df.isnull().sum()
# Out:
# gender                 0
# age_year               0
# fever                  0
# cough                  0
# runny_nose             0
# muscle_soreness        0
# pneumonia              0
# diarrhea               0
# lung_infection         0
# travel_history         0
# isolation_treatment    0
# SARS-CoV-2 Positive    0
# dtype: int64

# %%
# Preview rows contain missing value
# NOte : There is no preview because the data is not null

# if df.isnull().any(axis=None):
#     print("Preview of data with null values")
#     print("Null values : ", df.isnull().sum().sum())
#     display(df[df.isnull().any(axis=1)])

# %%
# Replace missing value with median value
# df = df.fillna(df.median())

# %% [markdown]
# The method chosen to overcome missing value is the median. <br>
# Reason: Columns that have a passing value have a categorical data type.

# %%
print("Null values : ",df.isnull().sum().sum())
print("Shape of data: ", df.shape)
# Out:
# Null values :  0
# Shape of data:  (6512, 12)

# %% [markdown]
# With the replace method, it can overcome missing values without reducing data

# %% [markdown]
# ## -- Check duplicate

# %%
# Check duplicate data
print("Data duplicated: ", df.duplicated().sum())
# Out:
# Data duplicated:  4285

# %% [markdown]
# ## -- Check imbalance data

# %%
# Check imbalance dataset
import seaborn as sns

sns.countplot(x=df['SARS-CoV-2 Positive'])
print(df['SARS-CoV-2 Positive'].value_counts())
# Out:
# 0    4940
# 1    1572
# Name: SARS-CoV-2 Positive, dtype: int64

# %% [markdown]
# # **Data Preprocessing**

# %% [markdown]
# ## -- Spitting features and label

# %%
features = df.drop(columns=['SARS-CoV-2 Positive'])
label = df[['SARS-CoV-2 Positive']]

print(features.shape)
print(label.shape)

features.columns, label.columns
# Out:
# (6512, 11)
# (6512, 1)
# (Index(['gender', 'age_year', 'fever', 'cough', 'runny_nose', 'muscle_soreness',
#         'pneumonia', 'diarrhea', 'lung_infection', 'travel_history',
#         'isolation_treatment'],
#        dtype='object'), Index(['SARS-CoV-2 Positive'], dtype='object'))

# %% [markdown]
# ## -- Check Data type
# Menyesuaikan tipe data sesuai dengan metadata yang diberikan
#
# * **Categorical** (`gender`, `fever`, `cough`, `runny_nose`, `muscle_soreness`, `pneumonia`, `diarrhea`, `lung_infection`, `travel_history`, `isolation_treatment`, `SARS-CoV-2 Positive`)
# * **Numeric** (`age_year`)

# %%
features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6512 entries, 0 to 6511
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   gender               6512 non-null   object
#  1   age_year             6512 non-null   int64
#  2   fever                6512 non-null   int64
#  3   cough                6512 non-null   int64
#  4   runny_nose           6512 non-null   int64
#  5   muscle_soreness      6512 non-null   int64
#  6   pneumonia            6512 non-null   int64
#  7   diarrhea             6512 non-null   int64
#  8   lung_infection       6512 non-null   int64
#  9   travel_history       6512 non-null   int64
#  10  isolation_treatment  6512 non-null   int64
# dtypes: int64(10), object(1)
# memory usage: 559.8+ KB

# %%
col_cat_features = ['gender', 'fever', 'cough', 'runny_nose', 'muscle_soreness',
       'pneumonia', 'diarrhea', 'lung_infection', 'travel_history',
       'isolation_treatment']

features[col_cat_features] = features[col_cat_features].astype('category')

# %%
features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6512 entries, 0 to 6511
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   gender               6512 non-null   category
#  1   age_year             6512 non-null   int64
#  2   fever                6512 non-null   category
#  3   cough                6512 non-null   category
#  4   runny_nose           6512 non-null   category
#  5   muscle_soreness      6512 non-null   category
#  6   pneumonia            6512 non-null   category
#  7   diarrhea             6512 non-null   category
#  8   lung_infection       6512 non-null   category
#  9   travel_history       6512 non-null   category
#  10  isolation_treatment  6512 non-null   category
# dtypes: category(10), int64(1)
# memory usage: 115.5 KB

# %%
label_types = ['Positive', 'Suspected']

# %% [markdown]
# ## -- Normalize Data

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
mx = MinMaxScaler()

# %%
features['age_year'] = mx.fit_transform(features[['age_year']])
features.head(2)
# Out:
#   gender  age_year fever  ... lung_infection travel_history isolation_treatment
# 0   male  0.926316     1  ...              0              1                   0
# 1   male  0.705263     1  ...              0              0                   0
#
# [2 rows x 11 columns]

# %% [markdown]
# ## -- Categorical

# %% [markdown]
# Change the categorical column to one hot encoding

# %%
features_cat = pd.get_dummies(features[col_cat_features])
features = pd.concat([features, features_cat], axis = 1)
features = features.drop(columns = col_cat_features)
features.head()
# Out:
#    age_year  gender_female  ...  isolation_treatment_0  isolation_treatment_1
# 0  0.926316              0  ...                      1                      0
# 1  0.705263              0  ...                      1                      0
# 2  0.705263              0  ...                      1                      0
# 3  0.705263              0  ...                      0                      1
# 4  0.515789              0  ...                      1                      0
#
# [5 rows x 21 columns]

# %%
# label_cat = pd.get_dummies(label['SARS-CoV-2 Positive'], prefix="sars")
# label = pd.concat([label, label_cat], axis = 1)
# label = label.drop(columns = 'SARS-CoV-2 Positive')
# label.head()

# %% [markdown]
# ## -- Split Data

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_validate, y_train, y_validate = train_test_split(
    features, label, test_size=0.3, shuffle=True, stratify=label)

# %%
X_train.shape, X_validate.shape
# Out:
# ((4558, 21), (1954, 21))

# %%
y_train.count()
# Out:
# SARS-CoV-2 Positive    4558
# dtype: int64

# %%
y_validate.count()
# Out:
# SARS-CoV-2 Positive    1954
# dtype: int64

# %% [markdown]
# # **Data Modelling**

# %% [markdown]
# ## -- Train Model

# %%
import tensorflow as tf

model = tf.keras.Sequential([
    tf.keras.layers.Dense(128, activation="relu", input_shape=(features.columns.size,)),
    tf.keras.layers.Dense(64, activation=tf.nn.relu),
    tf.keras.layers.Dense(32, activation=tf.nn.relu),
    tf.keras.layers.Dense(1, activation="sigmoid")
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 128)               2816
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 13,185
# Trainable params: 13,185
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    loss='binary_crossentropy',
    optimizer='Adam',
    metrics=['accuracy']
)

# %%
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('accuracy')>0.95 and logs.get('val_accuracy')>0.95):
      self.model.stop_training = True
      print("\nThe accuracy of the training set and the validation set has reached > 95%!")
callbacks = myCallback()

# %%
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
# simple early stopping
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=50)

# %%
mc = ModelCheckpoint('covid_model_04.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)

# %%
history = model.fit(
    X_train, 
    y_train, 
    validation_data=(X_validate, y_validate), 
    epochs=500, 
    batch_size=128, 
    callbacks=[es, mc], 
    verbose=2
)

history.history['accuracy'][-1]
# Out:
# Epoch 1/500
# 36/36 - 1s - loss: 0.4463 - accuracy: 0.8056 - val_loss: 0.2888 - val_accuracy: 0.8516
#
# Epoch 00001: val_accuracy improved from -inf to 0.85159, saving model to covid_model_04.h5
# Epoch 2/500
# 36/36 - 0s - loss: 0.2688 - accuracy: 0.8679 - val_loss: 0.2487 - val_accuracy: 0.8900
#
# Epoch 00002: val_accuracy improved from 0.85159 to 0.88997, saving model to covid_model_04.h5
# Epoch 3/500
# 36/36 - 0s - loss: 0.2485 - accuracy: 0.8883 - val_loss: 0.2528 - val_accuracy: 0.8910
#
# Epoch 00003: val_accuracy improved from 0.88997 to 0.89099, saving model to covid_model_04.h5
# Epoch 4/500
# 36/36 - 0s - loss: 0.2418 - accuracy: 0.8888 - val_loss: 0.2368 - val_accuracy: 0.9038
#
# Epoch 00004: val_accuracy improved from 0.89099 to 0.90379, saving model to covid_model_04.h5
# Epoch 5/500
# 36/36 - 0s - loss: 0.2379 - accuracy: 0.8899 - val_loss: 0.2328 - val_accuracy: 0.8956
#
# Epoch 00005: val_accuracy did not improve from 0.90379
# Epoch 6/500
# 36/36 - 0s - loss: 0.2374 - accuracy: 0.8916 - val_loss: 0.2334 - val_accuracy: 0.8961
#
# Epoch 00006: val_accuracy did not improve from 0.90379
# Epoch 7/500
# 36/36 - 0s - loss: 0.2390 - accuracy: 0.8892 - val_loss: 0.2313 - val_accuracy: 0.9038
#
# Epoch 00007: val_accuracy did not improve from 0.90379
# Epoch 8/500
# 36/36 - 0s - loss: 0.2324 - accuracy: 0.8929 - val_loss: 0.2324 - val_accuracy: 0.8920
#
# Epoch 00008: val_accuracy did not improve from 0.90379
# Epoch 9/500
# 36/36 - 0s - loss: 0.2329 - accuracy: 0.8993 - val_loss: 0.2308 - val_accuracy: 0.8895
#
# Epoch 00009: val_accuracy did not improve from 0.90379
# Epoch 10/500
# 36/36 - 0s - loss: 0.2329 - accuracy: 0.8875 - val_loss: 0.2316 - val_accuracy: 0.8905
#
# Epoch 00010: val_accuracy did not improve from 0.90379
# Epoch 11/500
# 36/36 - 0s - loss: 0.2329 - accuracy: 0.8907 - val_loss: 0.2319 - val_accuracy: 0.8946
#
# Epoch 00011: val_accuracy did not improve from 0.90379
# Epoch 12/500
# 36/36 - 0s - loss: 0.2311 - accuracy: 0.8936 - val_loss: 0.2328 - val_accuracy: 0.8900
#
# Epoch 00012: val_accuracy did not improve from 0.90379
# Epoch 13/500
# 36/36 - 0s - loss: 0.2304 - accuracy: 0.8936 - val_loss: 0.2302 - val_accuracy: 0.9007
#
# Epoch 00013: val_accuracy did not improve from 0.90379
# Epoch 14/500
# 36/36 - 0s - loss: 0.2289 - accuracy: 0.8953 - val_loss: 0.2327 - val_accuracy: 0.9038
#
# Epoch 00014: val_accuracy did not improve from 0.90379
# Epoch 15/500
# 36/36 - 0s - loss: 0.2287 - accuracy: 0.8964 - val_loss: 0.2316 - val_accuracy: 0.8941
#
# Epoch 00015: val_accuracy did not improve from 0.90379
# Epoch 16/500
# 36/36 - 0s - loss: 0.2289 - accuracy: 0.8949 - val_loss: 0.2302 - val_accuracy: 0.8936
#
# Epoch 00016: val_accuracy did not improve from 0.90379
# Epoch 17/500
# 36/36 - 0s - loss: 0.2302 - accuracy: 0.8949 - val_loss: 0.2326 - val_accuracy: 0.8889
#
# Epoch 00017: val_accuracy did not improve from 0.90379
# Epoch 18/500
# 36/36 - 0s - loss: 0.2273 - accuracy: 0.8949 - val_loss: 0.2317 - val_accuracy: 0.8915
#
# Epoch 00018: val_accuracy did not improve from 0.90379
# Epoch 19/500
# 36/36 - 0s - loss: 0.2292 - accuracy: 0.8929 - val_loss: 0.2346 - val_accuracy: 0.9048
#
# Epoch 00019: val_accuracy improved from 0.90379 to 0.90481, saving model to covid_model_04.h5
# Epoch 20/500
# 36/36 - 0s - loss: 0.2304 - accuracy: 0.8932 - val_loss: 0.2297 - val_accuracy: 0.8987
#
# Epoch 00020: val_accuracy did not improve from 0.90481
# Epoch 21/500
# 36/36 - 0s - loss: 0.2271 - accuracy: 0.8947 - val_loss: 0.2345 - val_accuracy: 0.9028
#
# Epoch 00021: val_accuracy did not improve from 0.90481
# Epoch 22/500
# 36/36 - 0s - loss: 0.2270 - accuracy: 0.8923 - val_loss: 0.2344 - val_accuracy: 0.8900
#
# Epoch 00022: val_accuracy did not improve from 0.90481
# Epoch 23/500
# 36/36 - 0s - loss: 0.2277 - accuracy: 0.8956 - val_loss: 0.2300 - val_accuracy: 0.8976
#
# Epoch 00023: val_accuracy did not improve from 0.90481
# Epoch 24/500
# 36/36 - 0s - loss: 0.2277 - accuracy: 0.8989 - val_loss: 0.2308 - val_accuracy: 0.8956
#
# Epoch 00024: val_accuracy did not improve from 0.90481
# Epoch 25/500
# 36/36 - 0s - loss: 0.2270 - accuracy: 0.8940 - val_loss: 0.2306 - val_accuracy: 0.9002
#
# Epoch 00025: val_accuracy did not improve from 0.90481
# Epoch 26/500
# 36/36 - 0s - loss: 0.2274 - accuracy: 0.8921 - val_loss: 0.2323 - val_accuracy: 0.8915
#
# Epoch 00026: val_accuracy did not improve from 0.90481
# Epoch 27/500
# 36/36 - 0s - loss: 0.2268 - accuracy: 0.8973 - val_loss: 0.2311 - val_accuracy: 0.8966
#
# Epoch 00027: val_accuracy did not improve from 0.90481
# Epoch 28/500
# 36/36 - 0s - loss: 0.2264 - accuracy: 0.8929 - val_loss: 0.2309 - val_accuracy: 0.8956
#
# Epoch 00028: val_accuracy did not improve from 0.90481
# Epoch 29/500
# 36/36 - 0s - loss: 0.2257 - accuracy: 0.8945 - val_loss: 0.2331 - val_accuracy: 0.9033
#
# Epoch 00029: val_accuracy did not improve from 0.90481
# Epoch 30/500
# 36/36 - 0s - loss: 0.2259 - accuracy: 0.8967 - val_loss: 0.2319 - val_accuracy: 0.8951
#
# Epoch 00030: val_accuracy did not improve from 0.90481
# Epoch 31/500
# 36/36 - 0s - loss: 0.2247 - accuracy: 0.8958 - val_loss: 0.2318 - val_accuracy: 0.9012
#
# Epoch 00031: val_accuracy did not improve from 0.90481
# Epoch 32/500
# 36/36 - 0s - loss: 0.2263 - accuracy: 0.8953 - val_loss: 0.2309 - val_accuracy: 0.8956
#
# Epoch 00032: val_accuracy did not improve from 0.90481
# Epoch 33/500
# 36/36 - 0s - loss: 0.2248 - accuracy: 0.8927 - val_loss: 0.2327 - val_accuracy: 0.8915
#
# Epoch 00033: val_accuracy did not improve from 0.90481
# Epoch 34/500
# 36/36 - 0s - loss: 0.2249 - accuracy: 0.8958 - val_loss: 0.2308 - val_accuracy: 0.8997
#
# Epoch 00034: val_accuracy did not improve from 0.90481
# Epoch 35/500
# 36/36 - 0s - loss: 0.2251 - accuracy: 0.8934 - val_loss: 0.2365 - val_accuracy: 0.8936
#
# Epoch 00035: val_accuracy did not improve from 0.90481
# Epoch 36/500
# 36/36 - 0s - loss: 0.2257 - accuracy: 0.8964 - val_loss: 0.2316 - val_accuracy: 0.9012
#
# Epoch 00036: val_accuracy did not improve from 0.90481
# Epoch 37/500
# 36/36 - 0s - loss: 0.2263 - accuracy: 0.8940 - val_loss: 0.2306 - val_accuracy: 0.8982
#
# Epoch 00037: val_accuracy did not improve from 0.90481
# Epoch 38/500
# 36/36 - 0s - loss: 0.2244 - accuracy: 0.8973 - val_loss: 0.2312 - val_accuracy: 0.8951
#
# Epoch 00038: val_accuracy did not improve from 0.90481
# Epoch 39/500
# 36/36 - 0s - loss: 0.2245 - accuracy: 0.8967 - val_loss: 0.2318 - val_accuracy: 0.9017
#
# Epoch 00039: val_accuracy did not improve from 0.90481
# Epoch 40/500
# 36/36 - 0s - loss: 0.2231 - accuracy: 0.8975 - val_loss: 0.2325 - val_accuracy: 0.9038
#
# Epoch 00040: val_accuracy did not improve from 0.90481
# Epoch 41/500
# 36/36 - 0s - loss: 0.2260 - accuracy: 0.8973 - val_loss: 0.2324 - val_accuracy: 0.8930
#
# Epoch 00041: val_accuracy did not improve from 0.90481
# Epoch 42/500
# 36/36 - 0s - loss: 0.2243 - accuracy: 0.8956 - val_loss: 0.2346 - val_accuracy: 0.8956
#
# Epoch 00042: val_accuracy did not improve from 0.90481
# Epoch 43/500
# 36/36 - 0s - loss: 0.2248 - accuracy: 0.8958 - val_loss: 0.2317 - val_accuracy: 0.9028
#
# Epoch 00043: val_accuracy did not improve from 0.90481
# Epoch 44/500
# 36/36 - 0s - loss: 0.2240 - accuracy: 0.8989 - val_loss: 0.2319 - val_accuracy: 0.8971
#
# Epoch 00044: val_accuracy did not improve from 0.90481
# Epoch 45/500
# 36/36 - 0s - loss: 0.2251 - accuracy: 0.8943 - val_loss: 0.2326 - val_accuracy: 0.9058
#
# Epoch 00045: val_accuracy improved from 0.90481 to 0.90583, saving model to covid_model_04.h5
# Epoch 46/500
# 36/36 - 0s - loss: 0.2238 - accuracy: 0.8953 - val_loss: 0.2316 - val_accuracy: 0.8941
#
# Epoch 00046: val_accuracy did not improve from 0.90583
# Epoch 47/500
# 36/36 - 0s - loss: 0.2244 - accuracy: 0.8956 - val_loss: 0.2313 - val_accuracy: 0.8987
#
# Epoch 00047: val_accuracy did not improve from 0.90583
# Epoch 48/500
# 36/36 - 0s - loss: 0.2231 - accuracy: 0.8962 - val_loss: 0.2343 - val_accuracy: 0.8971
#
# Epoch 00048: val_accuracy did not improve from 0.90583
# Epoch 49/500
# 36/36 - 0s - loss: 0.2256 - accuracy: 0.8967 - val_loss: 0.2335 - val_accuracy: 0.8915
#
# Epoch 00049: val_accuracy did not improve from 0.90583
# Epoch 50/500
# 36/36 - 0s - loss: 0.2242 - accuracy: 0.8940 - val_loss: 0.2321 - val_accuracy: 0.8966
#
# Epoch 00050: val_accuracy did not improve from 0.90583
# Epoch 51/500
# 36/36 - 0s - loss: 0.2249 - accuracy: 0.8982 - val_loss: 0.2317 - val_accuracy: 0.8982
#
# Epoch 00051: val_accuracy did not improve from 0.90583
# Epoch 52/500
# 36/36 - 0s - loss: 0.2225 - accuracy: 0.8943 - val_loss: 0.2316 - val_accuracy: 0.8910
#
# Epoch 00052: val_accuracy did not improve from 0.90583
# Epoch 53/500
# 36/36 - 0s - loss: 0.2232 - accuracy: 0.8980 - val_loss: 0.2333 - val_accuracy: 0.9053
#
# Epoch 00053: val_accuracy did not improve from 0.90583
# Epoch 54/500
# 36/36 - 0s - loss: 0.2248 - accuracy: 0.8971 - val_loss: 0.2331 - val_accuracy: 0.8925
#
# Epoch 00054: val_accuracy did not improve from 0.90583
# Epoch 55/500
# 36/36 - 0s - loss: 0.2231 - accuracy: 0.8943 - val_loss: 0.2321 - val_accuracy: 0.8930
#
# Epoch 00055: val_accuracy did not improve from 0.90583
# Epoch 56/500
# 36/36 - 0s - loss: 0.2237 - accuracy: 0.8962 - val_loss: 0.2313 - val_accuracy: 0.9033
#
# Epoch 00056: val_accuracy did not improve from 0.90583
# Epoch 57/500
# 36/36 - 0s - loss: 0.2219 - accuracy: 0.8932 - val_loss: 0.2335 - val_accuracy: 0.8920
#
# Epoch 00057: val_accuracy did not improve from 0.90583
# Epoch 58/500
# 36/36 - 0s - loss: 0.2243 - accuracy: 0.8967 - val_loss: 0.2330 - val_accuracy: 0.9033
#
# Epoch 00058: val_accuracy did not improve from 0.90583
# Epoch 59/500
# 36/36 - 0s - loss: 0.2231 - accuracy: 0.8971 - val_loss: 0.2323 - val_accuracy: 0.9007
#
# Epoch 00059: val_accuracy did not improve from 0.90583
# Epoch 60/500
# 36/36 - 0s - loss: 0.2234 - accuracy: 0.8949 - val_loss: 0.2324 - val_accuracy: 0.9023
#
# Epoch 00060: val_accuracy did not improve from 0.90583
# Epoch 61/500
# 36/36 - 0s - loss: 0.2220 - accuracy: 0.8973 - val_loss: 0.2315 - val_accuracy: 0.8936
#
# Epoch 00061: val_accuracy did not improve from 0.90583
# Epoch 62/500
# 36/36 - 0s - loss: 0.2210 - accuracy: 0.8969 - val_loss: 0.2316 - val_accuracy: 0.8956
#
# Epoch 00062: val_accuracy did not improve from 0.90583
# Epoch 63/500
# 36/36 - 0s - loss: 0.2214 - accuracy: 0.8980 - val_loss: 0.2327 - val_accuracy: 0.8951
#
# Epoch 00063: val_accuracy did not improve from 0.90583
# Epoch 64/500
# 36/36 - 0s - loss: 0.2217 - accuracy: 0.8984 - val_loss: 0.2327 - val_accuracy: 0.8992
#
# Epoch 00064: val_accuracy did not improve from 0.90583
# Epoch 65/500
# 36/36 - 0s - loss: 0.2211 - accuracy: 0.8989 - val_loss: 0.2322 - val_accuracy: 0.9017
#
# Epoch 00065: val_accuracy did not improve from 0.90583
# Epoch 66/500
# 36/36 - 0s - loss: 0.2224 - accuracy: 0.8918 - val_loss: 0.2328 - val_accuracy: 0.9012
#
# Epoch 00066: val_accuracy did not improve from 0.90583
# Epoch 67/500
# 36/36 - 0s - loss: 0.2219 - accuracy: 0.9008 - val_loss: 0.2320 - val_accuracy: 0.8961
#
# Epoch 00067: val_accuracy did not improve from 0.90583
# Epoch 68/500
# 36/36 - 0s - loss: 0.2211 - accuracy: 0.8975 - val_loss: 0.2323 - val_accuracy: 0.8951
#
# Epoch 00068: val_accuracy did not improve from 0.90583
# Epoch 69/500
# 36/36 - 0s - loss: 0.2219 - accuracy: 0.8956 - val_loss: 0.2315 - val_accuracy: 0.8951
#
# Epoch 00069: val_accuracy did not improve from 0.90583
# Epoch 70/500
# 36/36 - 0s - loss: 0.2207 - accuracy: 0.8978 - val_loss: 0.2325 - val_accuracy: 0.8956
#
# Epoch 00070: val_accuracy did not improve from 0.90583
# Epoch 00070: early stopping
# 0.8977621793746948

# %%
_, train_acc = model.evaluate(X_train, y_train, verbose=0)
_, valid_acc = model.evaluate(X_validate, y_validate, verbose=0)
print('Train: %.3f, Valid: %.3f' % (train_acc, valid_acc))
# Out:
# Train: 0.900, Valid: 0.896

# %%
from keras.models import load_model
saved_model = load_model('covid_model_04.h5')
_, train_acc = saved_model.evaluate(X_train, y_train, verbose=0)
_, valid_acc = saved_model.evaluate(X_validate, y_validate, verbose=0)
print('Train: %.3f, Valid: %.3f' % (train_acc, valid_acc))
# Out:
# Train: 0.896, Valid: 0.906

# %% [markdown]
# ## -- Plot Model

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'], color='red')
plt.plot(history.history['val_accuracy'], color='blue')
plt.ylim(top=1)
plt.title('Akurasi Model')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'], color='red')
plt.plot(history.history['val_loss'], color='blue')
plt.title('Loss Model')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# ## -- Predict and Evaluate Model

# %%
predictions = model.predict(X_validate)
predictions
# Out:
# array([[0.01071674],
#        [0.575117  ],
#        [0.46583378],
#        ...,
#        [0.06362325],
#        [0.04367021],
#        [0.0107975 ]], dtype=float32)

# %%
y_pred = np.where(predictions < 0.5, 0, 1)
y_pred
# Out:
# array([[0],
#        [1],
#        [0],
#        ...,
#        [0],
#        [0],
#        [0]])

# %%
y_validate
# Out:
#       SARS-CoV-2 Positive
# 3952                    0
# 4841                    0
# 426                     1
# 1532                    0
# 327                     1
# ...                   ...
# 583                     0
# 5467                    0
# 1550                    0
# 2647                    0
# 2865                    0
#
# [1954 rows x 1 columns]

# %%
# y_pred = np.argmax(predictions, axis=1)
# y_validate = np.argmax(y_validate.values, axis=1)

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y_validate, y_pred)
# Out:
# 0.8955987717502559

# %%
from sklearn import metrics
from sklearn.metrics import f1_score, confusion_matrix, accuracy_score

# %%
ac= accuracy_score(y_validate, y_pred)
print('Accuracy is:', ac)
cm = confusion_matrix(y_validate, y_pred)
sns.heatmap(cm,annot=True,fmt='d')
# Out:
# Accuracy is: 0.8955987717502559

# %%
from sklearn.metrics import classification_report

# %%
from sklearn.metrics import classification_report, confusion_matrix
cm = np.array(confusion_matrix(y_validate, y_pred, labels=[1,0])) # positive-1, suspected-0
confusion = pd.DataFrame(cm, index=['is_covid', 'is_suspected'],
                         columns=['predicted_covid', 'predicted_suspected'])
confusion
# Out:
#               predicted_covid  predicted_suspected
# is_covid                  348                  124
# is_suspected               80                 1402

# %%
print('Acc',classification_report(y_validate, y_pred))
# Out:
# Acc               precision    recall  f1-score   support
#
#            0       0.92      0.95      0.93      1482
#            1       0.81      0.74      0.77       472
#
#     accuracy                           0.90      1954
#    macro avg       0.87      0.84      0.85      1954
# weighted avg       0.89      0.90      0.89      1954

# %% [markdown]
# ## -- Experiment

# %% [markdown]
# ### **Effect of Batch Size on Model Behavior**

# %%
from keras.optimizers import SGD
# fit a model and plot learning curve
def fit_model(X_train, y_train, X_validate, y_validate, n_batch):
  model = tf.keras.Sequential([
    tf.keras.layers.Dense(128, activation="relu", input_shape=(features.columns.size,)),
    tf.keras.layers.Dense(64, activation=tf.nn.relu),
    tf.keras.layers.Dense(32, activation=tf.nn.relu),
    tf.keras.layers.Dense(1, activation="sigmoid")
  ])
  model.compile(loss='binary_crossentropy',
    optimizer="adam",
    metrics=['accuracy'])
  
  history = model.fit(X_train, y_train, validation_data=(X_validate, y_validate), epochs=500, batch_size=n_batch, verbose=0)

  plt.plot(history.history['accuracy'], label='train')
  plt.plot(history.history['val_accuracy'], label='test')
  plt.ylim(top=1)
  plt.title('batch='+str(n_batch))
  plt.legend()

# %%
batch_sizes = [4, 8, 16, 32, 64, 128, 256, 450, 500]

plt.figure(figsize=(10, 15))
for i in range(len(batch_sizes)):
    
    # determine the plot number
    plot_no = 520 + (i+1)
    plt.subplot(plot_no)
    
    # fit model and plot learning curves for a batch size
    fit_model(X_train, y_train, X_validate, y_validate, batch_sizes[i])

# show learning curves
plt.show()

# %% [markdown]
# ### **Effect of Epoch on Model Behavior**

# %%
# fit a model and plot learning curve
def fit_model(X_train, y_train, X_validate, y_validate, n_epoch):
  model = tf.keras.Sequential([
    tf.keras.layers.Dense(128, activation="relu", input_shape=(features.columns.size,)),
    tf.keras.layers.Dense(64, activation=tf.nn.relu),
    tf.keras.layers.Dense(32, activation=tf.nn.relu),
    tf.keras.layers.Dense(1, activation="sigmoid")
  ])
  model.compile(loss='binary_crossentropy',
    optimizer="adam",
    metrics=['accuracy'])
  
  history = model.fit(X_train, y_train, validation_data=(X_validate, y_validate), epochs=n_epoch, batch_size=64, verbose=0)

  plt.plot(history.history['accuracy'], label='train')
  plt.plot(history.history['val_accuracy'], label='test')
  plt.ylim(top=1)
  plt.title('Epoch='+str(n_epoch))
  plt.legend()

# %%
epoch_sizes = [50, 100, 150, 200, 250, 300, 350, 400, 450, 500]

plt.figure(figsize=(10, 20))
for i in range(len(epoch_sizes)):
    
    # determine the plot number
    plt.subplot(5, 2, i+1)
    
    # fit model and plot learning curves for a batch size
    fit_model(X_train, y_train, X_validate, y_validate, epoch_sizes[i])

# show learning curves
plt.show()

# %% [markdown]
# ### **Summary Effect of Epoch and Batch Size on Model Behavior**

# %%
# fit a model and plot learning curve
def fit_model(X_train, y_train, X_validate, y_validate, n_batch, n_epoch):
  model = tf.keras.Sequential([
    tf.keras.layers.Dense(128, activation="relu", input_shape=(features.columns.size,)),
    tf.keras.layers.Dense(64, activation=tf.nn.relu),
    tf.keras.layers.Dense(32, activation=tf.nn.relu),
    tf.keras.layers.Dense(1, activation="sigmoid")
  ])
  model.compile(loss='binary_crossentropy',
    optimizer="adam",
    metrics=['accuracy'])
  
  history = model.fit(X_train, y_train, validation_data=(X_validate, y_validate), epochs=n_epoch, batch_size=n_batch, verbose=0)
  plt.plot(history.history['accuracy'], label='train')
  plt.plot(history.history['val_accuracy'], label='test')
  plt.ylim(top=1)
  plt.title('Epoch = '+str(n_epoch))
  plt.legend()

# %%
batch_sizes = [4, 8, 16, 32, 64, 128, 256, 450, 500]
epoch_sizes = [50, 100, 150, 200, 250, 300, 350, 400, 450, 500]

for batch in batch_sizes:
  print("Batch = ", batch)
  plt.figure(figsize=(10, 20))
  for i in range(len(epoch_sizes)):
    # determine the plot number
    plt.subplot(5,2,i+1)
    
    # fit model and plot learning curves for a batch size
    fit_model(X_train, y_train, X_validate, y_validate, batch, epoch_sizes[i])
  # show learning curves
  plt.show()
# Out:
# Batch =  4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-65-75905ff30b1e> in <module>()
#      10
#      11     # fit model and plot learning curves for a batch size
# ---> 12     fit_model(X_train, y_train, X_validate, y_validate, batch, epoch_sizes[i])
#      13   # show learning curves
#      14   plt.show()
#
# <ipython-input-64-d088039667f7> in fit_model(X_train, y_train, X_validate, y_validate, n_batch, n_epoch)
#      11     metrics=['accuracy'])
#      12
# ---> 13   history = model.fit(X_train, y_train, validation_data=(X_validate, y_validate), epochs=n_epoch, batch_size=n_batch, verbose=0)
#      14   plt.plot(history.history['accuracy'], label='train')
#      15   plt.plot(history.history['val_accuracy'], label='test')
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1223               use_multiprocessing=use_multiprocessing,
#    1224               return_dict=True,
# -> 1225               _use_cached_eval_dataset=True)
#    1226           val_logs = {'val_' + name: val for name, val in val_logs.items()}
#    1227           epoch_logs.update(val_logs)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict, **kwargs)
#    1487             with trace.Trace('test', step_num=step, _r=1):
#    1488               callbacks.on_test_batch_begin(step)
# -> 1489               tmp_logs = self.test_function(iterator)
#    1490               if data_handler.should_sync:
#    1491                 context.async_wait()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     887
#     888       with OptionalXlaContext(self._jit_compile):
# --> 889         result = self._call(*args, **kwds)
#     890
#     891       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     922       # In this case we have not created variables on the first call. So we can
#     923       # run the first trace but we should fail if variables are created.
# --> 924       results = self._stateful_fn(*args, **kwds)
#     925       if self._created_variables:
#     926         raise ValueError("Creating variables on a non-first call to a function"
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    3022        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    3023     return graph_function._call_flat(
# -> 3024         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3025
#    3026   @property
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1959       # No tape is watching; skip to running the function.
#    1960       return self._build_call_outputs(self._inference_function.call(
# -> 1961           ctx, args, cancellation_manager=cancellation_manager))
#    1962     forward_backward = self._select_forward_and_backward_functions(
#    1963         args,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     594               inputs=args,
#     595               attrs=attrs,
# --> 596               ctx=ctx)
#     597         else:
#     598           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# ### **Effect of Activation Function on Model Behavior**

# %%
# fit a model and plot learning curve
def fit_model(X_train, y_train, X_validate, y_validate, activations, output_activations):
  model = tf.keras.Sequential([
    tf.keras.layers.Dense(128, activation=activations, input_shape=(features.columns.size,)),
    tf.keras.layers.Dense(64, activation=activations),
    tf.keras.layers.Dense(32, activation=activations),
    tf.keras.layers.Dense(1, activation=output_activations)
  ])
  model.compile(loss='binary_crossentropy',
    optimizer="adam",
    metrics=['accuracy'])
  
  history = model.fit(X_train, y_train, validation_data=(X_validate, y_validate), epochs=200, batch_size=128, verbose=0)
  plt.plot(history.history['accuracy'], label='train')
  plt.plot(history.history['val_accuracy'], label='test')
  plt.ylim(top=1)
  plt.title('Activations = '+activations+ ', output = '+output_activations)
  plt.legend()

# %%
activations = ["relu", "tanh"]
output_activations = ["sigmoid", "softmax"]

for activation in activations:
  print("Activation = ", activation)
  plt.figure(figsize=(10, 20))
  for i in range(len(output_activations)):
    # determine the plot number
    plt.subplot(5,2,i+1)
    
    # fit model and plot learning curves for a activation size
    fit_model(X_train, y_train, X_validate, y_validate, activation, output_activations[i])
  # show learning curves
  plt.show()

# %% [markdown]
# ### **Effect of Loss Functions on Model Behavior**

# %%
# fit a model and plot learning curve
def fit_model(X_train, y_train, X_validate, y_validate, loss):
  model = tf.keras.Sequential([
    tf.keras.layers.Dense(128, activation=activations, input_shape=(features.columns.size,)),
    tf.keras.layers.Dense(64, activation=activations),
    tf.keras.layers.Dense(32, activation=activations),
    tf.keras.layers.Dense(1, activation=output_activations)
  ])
  model.compile(loss=loss,
    optimizer="adam",
    metrics=['accuracy'])
  
  history = model.fit(X_train, y_train, validation_data=(X_validate, y_validate), epochs=200, batch_size=128, verbose=0)

  plt.plot(history.history['accuracy'], label='train')
  plt.plot(history.history['val_accuracy'], label='test')
  plt.ylim(top=1)
  plt.title('Loss='+str(loss))
  plt.legend()

# %%
loss = ["binary_crossentropy", "categorical_crossentropy", 'sparse_categorical_crossentropy']

plt.figure(figsize=(10, 20))
for i in range(len(loss)):
    
    # determine the plot number
    plt.subplot(5, 2, i+1)
    
    # fit model and plot learning curves for a batch size
    fit_model(X_train, y_train, X_validate, y_validate, loss[i])

# show learning curves
plt.show()

# %% [markdown]
# ### **Effect of Learning Rate (SGD) on Model Behavior**

# %%
# fit a model and plot learning curve
def fit_model(X_train, y_train, X_validate, y_validate, n_batch, learning_rate):
  model = tf.keras.Sequential([
    tf.keras.layers.Dense(128, activation=activations, input_shape=(features.columns.size,)),
    tf.keras.layers.Dense(64, activation=activations),
    tf.keras.layers.Dense(32, activation=activations),
    tf.keras.layers.Dense(1, activation=output_activations)
  ])
  opt = SGD(lr=learning_rate, momentum=0.9)
  model.compile(
    loss='binary_crossentropy',
    optimizer=opt,
    metrics=['accuracy']
  )

  history = model.fit(X_train, y_train, validation_data=(X_validate, y_validate), epochs=200, batch_size=n_batch, verbose=0)
  plt.plot(history.history['accuracy'], label='train')
  plt.plot(history.history['val_accuracy'], label='test')
  plt.ylim(top=1)
  plt.title('Learning Rate = '+str(learning_rate))
  plt.legend()

# %%
batch_sizes = [4, 8, 16, 32, 64, 128, 256, 450, 500]
learning_rate = [1, 1E-1, 1E-2, 1E-3, 1E-4, 1E-5]

for batch in batch_sizes:
  print("Batch = ", batch)
  plt.figure(figsize=(10, 20))
  for i in range(len(learning_rate)):
    # determine the plot number
    plt.subplot(3,2,i+1)
    
    # fit model and plot learning curves for a batch size
    fit_model(X_train, y_train, X_validate, y_validate, batch, learning_rate[i])
  # show learning curves
  plt.show()

# %% [markdown]
# ### **Effect of Optimizer on Model Behavior**

# %%
# fit a model and plot learning curve
def fit_model(X_train, y_train, X_validate, y_validate, n_batch, optimizer):
  model = tf.keras.Sequential([
    tf.keras.layers.Dense(128, activation=activations, input_shape=(features.columns.size,)),
    tf.keras.layers.Dense(64, activation=activations),
    tf.keras.layers.Dense(32, activation=activations),
    tf.keras.layers.Dense(1, activation=output_activations)
  ])
  model.compile(
    loss='binary_crossentropy',
    optimizer=optimizer,
    metrics=['accuracy']
  )

  history = model.fit(X_train, y_train, validation_data=(X_validate, y_validate), epochs=200, batch_size=n_batch, verbose=0)
  plt.plot(history.history['accuracy'], label='train')
  plt.plot(history.history['val_accuracy'], label='test')
  plt.ylim(top=1)
  plt.title('optimizer = '+str(optimizer))
  plt.legend()

# %%
batch_sizes = [4, 8, 16, 32, 64, 128, 256, 450, 500]
optimizer = ['adam', 'sgd', 'rmsprop', 'adagrad']

for batch in batch_sizes:
  print("Batch = ", batch)
  plt.figure(figsize=(10, 20))
  for i in range(len(optimizer)):
    # determine the plot number
    plt.subplot(3,2,i+1)
    
    # fit model and plot learning curves for a batch size
    fit_model(X_train, y_train, X_validate, y_validate, batch, optimizer[i])
  # show learning curves
  plt.show()

# %% [markdown]
# ## -- Save Model

# %%
import tempfile
MODEL_DIR = tempfile.gettempdir()

version = 1

export_path = os.path.join(MODEL_DIR, str(version))

if os.path.isdir(export_path):
    print('\nAlready saved a model, cleaning up\n')
    # !rm -r {export_path}

model.save(export_path, save_format="tf")

print('\nexport_path = {}'.format(export_path))
# !ls -l {export_path}

# %%
# Intialize the TFLite converter to load the SavedModel
converter = tf.lite.TFLiteConverter.from_saved_model(export_path)

# Set the optimization strategy for 'size' in the converter 
converter.optimizations = [tf.lite.Optimize.OPTIMIZE_FOR_SIZE]

# Use the tool to finally convert the model
tflite_model = converter.convert()

# Write TFLite model
tflite_model_file = 'covid_model_04.tflite'

with open(tflite_model_file, "wb") as f:
    f.write(tflite_model)

with open('covid_labels_04.txt', 'w') as f:
    f.write('\n'.join(label_types))

# %%
try:
    files.download('covid_model_04.tflite')
    files.download('covid_labels_04.txt')
except:
    pass

# %% [markdown]
# ## -- Save Model 02 for covid_model_04.h5

# %%
import tempfile
MODEL_DIR = tempfile.gettempdir()

version = 2

export_path = os.path.join(MODEL_DIR, str(version))

if os.path.isdir(export_path):
    print('\nAlready saved a model, cleaning up\n')
    # !rm -r {export_path}

saved_model.save(export_path, save_format="tf")

print('\nexport_path = {}'.format(export_path))
# !ls -l {export_path}

# %%
# Intialize the TFLite converter to load the SavedModel
converter = tf.lite.TFLiteConverter.from_saved_model(export_path)

# Set the optimization strategy for 'size' in the converter 
converter.optimizations = [tf.lite.Optimize.OPTIMIZE_FOR_SIZE]

# Use the tool to finally convert the model
tflite_model = converter.convert()

# Write TFLite model
tflite_model_file = 'covid_model_04_v2.tflite'

with open(tflite_model_file, "wb") as f:
    f.write(tflite_model)

with open('covid_labels_04_v2.txt', 'w') as f:
    f.write('\n'.join(label_types))

# %%
try:
    files.download('covid_model_04_v2.tflite')
    files.download('covid_labels_04_v2.txt')
except:
    pass
